# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Data/MNCAATourneyDetailedResults.csv')

# %%
df
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0       2003     134     1421      92     1411      84    N      1    32
# 1       2003     136     1112      80     1436      51    N      0    31
# 2       2003     136     1113      84     1272      71    N      0    31
# 3       2003     136     1141      79     1166      73    N      0    29
# 4       2003     136     1143      76     1301      74    N      1    27
# ...      ...     ...      ...     ...      ...     ...  ...    ...   ...
# 1110    2019     146     1120      77     1246      71    N      1    26
# 1111    2019     146     1277      68     1181      67    N      0    30
# 1112    2019     152     1403      61     1277      51    N      0    22
# 1113    2019     152     1438      63     1120      62    N      0    25
# 1114    2019     154     1438      85     1403      77    N      1    27
#
#       WFGA  ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# ...

# %%
def possessions(row):
    if 'WFGA' in row:
        possessions = 0.96*(row.WFGA + row.WTO + 0.44*row.WFTA - row.WOR)
    else:
        possessions = 0.96*(row.LFGA + row.LTO + 0.44*row.LFTA - row.LOR)
    return possessions

df['wPoss'] = df[['WFGA', 'WTO', 'WFTA', 'WOR']].apply(possessions, axis=1)
df['lPoss'] = df[['LFGA', 'LTO', 'LFTA', 'LOR']].apply(possessions, axis=1)

# %%
# total possession
df['Poss'] = (df['wPoss'] + df['lPoss']) / 2

# %%
df
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0       2003     134     1421      92     1411      84    N      1    32
# 1       2003     136     1112      80     1436      51    N      0    31
# 2       2003     136     1113      84     1272      71    N      0    31
# 3       2003     136     1141      79     1166      73    N      0    29
# 4       2003     136     1143      76     1301      74    N      1    27
# ...      ...     ...      ...     ...      ...     ...  ...    ...   ...
# 1110    2019     146     1120      77     1246      71    N      1    26
# 1111    2019     146     1277      68     1181      67    N      0    30
# 1112    2019     152     1403      61     1277      51    N      0    22
# 1113    2019     152     1438      63     1120      62    N      0    25
# 1114    2019     154     1438      85     1403      77    N      1    27
#
#       WFGA  ...  LOR  LDR  LAst  LTO  LStl  LBlk  LPF    wPoss    lPoss  \
# ...

# %%
def offReb(row):
    print(row)
